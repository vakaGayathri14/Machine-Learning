# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# working with dates

# %%
#converting to date time datatype

date['date'] = pd.to_datetime(date['date'])

# %%
date['date']
# Out:
# 0     2019-12-10
# 1     2018-08-15
# 2     2018-10-23
# 3     2019-08-17
# 4     2019-01-06
#          ...
# 995   2018-10-08
# 996   2018-12-06
# 997   2019-05-07
# 998   2019-03-03
# 999   2019-10-15
# Name: date, Length: 1000, dtype: datetime64[ns]

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# 1. Etract year

# %%
date['date_year'] = date['date'].dt.year

# %%
date['date_year']
# Out:
# 0      2019
# 1      2018
# 2      2018
# 3      2019
# 4      2019
#        ...
# 995    2018
# 996    2018
# 997    2019
# 998    2019
# 999    2019
# Name: date_year, Length: 1000, dtype: int32

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018
# 3 2019-08-17        7292       25       1       2019
# 4 2019-01-06        4344       25       3       2019

# %% [markdown]
# Extract month

# %%
date['date_month'] = date['date'].dt.month

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1

# %% [markdown]
# month name

# %%
date['date_month'] = date['date'].dt.month_name()

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month
# 0 2019-12-10        5628       25       3       2019   December
# 1 2018-08-15        3646       14     157       2018     August
# 2 2018-10-23        1859       25       1       2018    October
# 3 2019-08-17        7292       25       1       2019     August
# 4 2019-01-06        4344       25       3       2019    January

# %% [markdown]
# Extract days

# %%
date['date_day'] = date['date'].dt.day

# %%
date['date_day']
# Out:
# 0      10
# 1      15
# 2      23
# 3      17
# 4       6
#        ..
# 995     8
# 996     6
# 997     7
# 998     3
# 999    15
# Name: date_day, Length: 1000, dtype: int32

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month  date_day
# 0 2019-12-10        5628       25       3       2019   December        10
# 1 2018-08-15        3646       14     157       2018     August        15
# 2 2018-10-23        1859       25       1       2018    October        23
# 3 2019-08-17        7292       25       1       2019     August        17
# 4 2019-01-06        4344       25       3       2019    January         6

# %%
#day of week

date['date_day_of_week'] = date['date'].dt.day_of_week

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month  date_day  \
# 0 2019-12-10        5628       25       3       2019   December        10
# 1 2018-08-15        3646       14     157       2018     August        15
# 2 2018-10-23        1859       25       1       2018    October        23
# 3 2019-08-17        7292       25       1       2019     August        17
# 4 2019-01-06        4344       25       3       2019    January         6
#
#    date_day_of_week
# 0                 1
# 1                 2
# 2                 1
# 3                 5
# 4                 6

# %%
#date of day

date['date_of_day'] = date['date'].dt.day_name()

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month  date_day  \
# 0 2019-12-10        5628       25       3       2019   December        10
# 1 2018-08-15        3646       14     157       2018     August        15
# 2 2018-10-23        1859       25       1       2018    October        23
# 3 2019-08-17        7292       25       1       2019     August        17
# 4 2019-01-06        4344       25       3       2019    January         6
#
#    date_day_of_week date_of_day
# 0                 1     Tuesday
# 1                 2   Wednesday
# 2                 1     Tuesday
# 3                 5    Saturday
# 4                 6      Sunday

# %%
# is weekend?

date['date_is_weekend'] = np.where(date['date_of_day'].isin(['Sunday','Saturday']),1,0)
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month  date_day  date_day_of_week date_of_day  \
# 0 2019-12-10       2019   December        10                 1     Tuesday
# 1 2018-08-15       2018     August        15                 2   Wednesday
# 2 2018-10-23       2018    October        23                 1     Tuesday
# 3 2019-08-17       2019     August        17                 5    Saturday
# 4 2019-01-06       2019    January         6                 6      Sunday
#
#    date_is_weekend
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1

# %% [markdown]
# Extract quarter

# %%
date['quarter'] = date['date'].dt.quarter

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month  date_day  \
# 0 2019-12-10        5628       25       3       2019   December        10
# 1 2018-08-15        3646       14     157       2018     August        15
# 2 2018-10-23        1859       25       1       2018    October        23
# 3 2019-08-17        7292       25       1       2019     August        17
# 4 2019-01-06        4344       25       3       2019    January         6
#
#    date_day_of_week date_of_day  date_is_weekend  week  quarter
# 0                 1     Tuesday                0     1        4
# 1                 2   Wednesday                0     2        3
# 2                 1     Tuesday                0     1        4
# 3                 5    Saturday                1     5        3
# 4                 6      Sunday                1     6        1

# %% [markdown]
# Extract Time elapsed between dates

# %%
import datetime

today = datetime.datetime.today()

# %%
today
# Out:
# datetime.datetime(2025, 12, 26, 9, 28, 45, 461667)

# %%
today-date['date']
# Out:
# 0     2208 days 09:28:45.461667
# 1     2690 days 09:28:45.461667
# 2     2621 days 09:28:45.461667
# 3     2323 days 09:28:45.461667
# 4     2546 days 09:28:45.461667
#                  ...
# 995   2636 days 09:28:45.461667
# 996   2577 days 09:28:45.461667
# 997   2425 days 09:28:45.461667
# 998   2490 days 09:28:45.461667
# 999   2264 days 09:28:45.461667
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %% [markdown]
# Time

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour']=time['date'].dt.hour

# %%
time.head()
# Out:
#                  date                                                msg  hour
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37     0
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826    23
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576     0
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...     0
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше    23

# %%
time['min'] = time['date'].dt.minute

# %%
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min
# 0     0   50
# 1    23   40
# 2     0   21
# 3     0   31
# 4    23   11

# %%
time['sec'] = time['date'].dt.second

# %%
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %%
time['time'] = time['date'].dt.time

# %%
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

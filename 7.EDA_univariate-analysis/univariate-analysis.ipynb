# %%
import pandas as pd

# %%
df = pd.read_csv('tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.shape
# Out:
# (418, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 114         1006         1       1     Straus, Mrs. Isidor (Rosalie Ida Blun)
# 221         1113         0       3                     Reynolds, Mr. Harold J
# 172         1064         0       3                   Dyker, Mr. Adolf Fredrik
# 104          996         1       3  Thomas, Mrs. Alexander (Thamine Thelma")"
# 91           983         0       3                         Pedersen, Mr. Olaf
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 114  female  63.0      1      0  PC 17483  221.7792  C55 C57        S
# 221    male  21.0      0      0    342684    8.0500      NaN        S
# 172    male  23.0      1      0    347072   13.9000      NaN        S
# 104  female  16.0      1      1      2625    8.5167      NaN        C
# 91     male   NaN      0      0    345498    7.7750      NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only = True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age            -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp           0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Survived     0.191514
# Pclass      -0.577147
# Age          0.337932
# SibSp        0.171539
# Parch        0.230046
# Fare         1.000000

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# Categorical Data

# %% [markdown]
# a.Countplot -> how many people are survived? how many not? this we use countplot

# %%
import seaborn as sns

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# EDA for PClass column

# %%
sns.countplot(data=df, x='Pclass', hue='Pclass', legend=False)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %% [markdown]
# EDA for sex column

# %%
sns.countplot(data = df, x='Sex', hue = 'Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# EDA for Embarked column

# %%
sns.countplot(data=df, x='Embarked', hue='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# if you want frequency count of categories the same information need in percentage then we use piechart

# %% [markdown]
# PieChart

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 2. Numerical Data

# %% [markdown]
# a. Histogram -> you can create ranges on numerical data.forexample dividing different age groups and plotting them

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([ 32., 168.,  80.,  42.,  10.]),
#  array([ 0.17 , 15.336, 30.502, 45.668, 60.834, 76.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# b. Displot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Gayathri\AppData\Local\Temp\ipykernel_11868\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(df['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Age'],kde=True, stat = "density")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c. Boxplot -> giving 5 number summary # udentifying outliers (stats)

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# np.float64(0.17)

# %%
df['Age'].max()
# Out:
# np.float64(76.0)

# %%
df['Age'].mean()
# Out:
# np.float64(30.272590361445783)

# %%
df['Age'].skew()
# Out:
# np.float64(0.4573612871503845)
